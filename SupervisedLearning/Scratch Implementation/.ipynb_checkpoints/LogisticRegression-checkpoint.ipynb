# %%
import numpy as np

# %%
import numpy as np

class LogisticRegression:
    def __init__(self, learning_rate=0.1, n_iter=1000):
        self.bias = None
        self.weights = None
        self.lr = learning_rate
        self.n_iter = n_iter

    def _sigmoid(self, z):
        return 1 / (1 + np.exp(-z))

    def fit(self, X, y):
        m, n = X.shape

        self.bias = 0
        self.weights = np.zeros(n)

        for _ in range(self.n_iter):
            z = self.bias + np.dot(X, self.weights)
            y_pred = self._sigmoid(z)

            db = (1 / m) * np.sum(y_pred - y)
            dw = (1 / m) * np.dot(X.T, (y_pred - y))

            self.bias -= self.lr * db
            self.weights -= self.lr * dw

    def get_probabilities(self, X):
        z = self.bias + np.dot(X, self.weights)
        return self._sigmoid(z)

    def predict(self, X, threshold=0.5):
        probabilities = self.get_probabilities(X)
        return (probabilities >= threshold).astype(int)

# %%
arr = np.array([0.67, 0.99, 0.23])
(arr >= 0.5).astype(int)
# Out:
# array([1, 1, 0])

# %%
X = np.array([[1,2],[3,4],[2,3],[4,5]])
y = np.array([0, 0, 1, 1])

model = LogisticRegression()
model.fit(X, y)

y_pred = model.predict(X)
print(y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 7
#       4 model = LogisticRegression()
#       5 model.fit(X, y)
# ----> 7 y_pred = model.predict(X)
#       8 print(y_pred)
#
# Cell In[20], line 36, in LogisticRegression.predict(self, X)
#      35 def predict(self, X):
# ---> 36     probabilities = self.get_probabilities(X)
#      37     y_pred_boolean = probabilities >= threshold
#      38     return y_pred_boolean.astype(int)
#
# Cell In[20], line 31, in LogisticRegression.get_probabilities(self, X)
#      30 def get_probabilities(self, X):
# ---> 31     z = self.bias + np.dot(X.T, self.weights)
#      32     y_pred = self._sigmoid(z)
#      33     return y_pred
#
# ValueError: shapes (2,4) and (2,) not aligned: 4 (dim 1) != 2 (dim 0)
